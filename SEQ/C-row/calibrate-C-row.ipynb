# %%
workdir = "/SNS/users/lj7/dv/sns-chops/detcalib/SEQ"
# %cd {workdir}
# Out:
# /SNS/users/lj7/dv/sns-chops/detcalib/SEQ

# %%
import sys, os, numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
sys.path.insert(0, "%s/lib"%workdir)

# %%
import calibrate
reload(calibrate)
# Out:
# <module 'calibrate' from '/SNS/users/lj7/dv/sns-chops/detcalib/SEQ/lib/calibrate.pyc'>

# %%
difc_C1, mask_C1 = calibrate.calibrate(
    pack = 'C1/eightpack', I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
    dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
    dmin=1.06, dmax=1.2,
    maxchisq = 5., min_counts = 1000,
    T0_of_E = calibrate.SEQ_T0_of_E,
    l2table_nxs = './L2table.nxs',
)
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# .* Not enough counts: 4
# * fit failed: pixel 4
# .* Not enough counts: 5
# * fit failed: pixel 5
# .* Not enough counts: 6
# * fit failed: pixel 6
# .* Not enough counts: 7
# * fit failed: pixel 7
# .* Not enough counts: 8
# * fit failed: pixel 8
# .* Not enough counts: 9
# * fit failed: pixel 9
# .* Not enough counts: 10
# * fit failed: pixel 10
# .* Not enough counts: 11
# * fit failed: pixel 11
# .* Not enough counts: 12
# * fit failed: pixel 12
# .* Not enough counts: 13
# * fit failed: pixel 13
# .* Not enough counts: 14
# * fit failed: pixel 14
# .* Not enough counts: 15
# * fit failed: pixel 15
# .* Not enough counts: 16
# * fit failed: pixel 16
# .* Not enough counts: 17
# * fit failed: pixel 17
# ...

# %% [markdown]
# C1: no data

# %%
difc_C2, mask_C2 = calibrate.calibrate(
    pack = 'C2/eightpack', I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
    dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
    dmin=1.06, dmax=1.2,
    maxchisq = 5., min_counts = 1000,
    T0_of_E = calibrate.SEQ_T0_of_E,
    l2table_nxs = './L2table.nxs',
)
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# .* Not enough counts: 4
# * fit failed: pixel 4
# .* Not enough counts: 5
# * fit failed: pixel 5
# .* Not enough counts: 6
# * fit failed: pixel 6
# .* Not enough counts: 7
# * fit failed: pixel 7
# .* Not enough counts: 8
# * fit failed: pixel 8
# .* Not enough counts: 9
# * fit failed: pixel 9
# .* Not enough counts: 10
# * fit failed: pixel 10
# .* Not enough counts: 11
# * fit failed: pixel 11
# .* Not enough counts: 12
# * fit failed: pixel 12
# .* Not enough counts: 13
# * fit failed: pixel 13
# .* Not enough counts: 14
# * fit failed: pixel 14
# .* Not enough counts: 15
# * fit failed: pixel 15
# .* Not enough counts: 16
# * fit failed: pixel 16
# .* Not enough counts: 17
# * fit failed: pixel 17
# ...

# %% [markdown]
# C2: no data

# %%
difc_C3, mask_C3 = calibrate.calibrate(
    pack = 'C3/eightpack', I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
    dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
    dmin=1.06, dmax=1.2,
    maxchisq = 5., min_counts = 1000,
    T0_of_E = calibrate.SEQ_T0_of_E,
    l2table_nxs = './L2table.nxs',
)
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# ................................................................................................- Working on pixel 100
# ........................* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .* Not enough counts: 131
# * fit failed: pixel 131
# ....................................................................- Working on pixel 200
# ...

# %% [markdown]
# 4-7

# %%
for i in range(4, 7+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=1.3, dmax=1.5,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# .* Not enough counts: 4
# * fit failed: pixel 4
# .* Not enough counts: 5
# * fit failed: pixel 5
# ..* Not enough counts: 7
# * fit failed: pixel 7
# .* Not enough counts: 8
# * fit failed: pixel 8
# ...* Not enough counts: 11
# * fit failed: pixel 11
# ...* Not enough counts: 14
# * fit failed: pixel 14
# ..* Not enough counts: 16
# * fit failed: pixel 16
# ..* Not enough counts: 18
# * fit failed: pixel 18
# .* Not enough counts: 19
# * fit failed: pixel 19
# ..* Not enough counts: 21
# * fit failed: pixel 21
# .* Not enough counts: 22
# * fit failed: pixel 22
# .* Not enough counts: 23
# * fit failed: pixel 23
# .* Not enough counts: 24
# * fit failed: pixel 24
# .* Not enough counts: 25
# * fit failed: pixel 25
# ...

# %% [markdown]
# 8-10

# %%
for i in range(8, 10+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=1.6, dmax=1.7,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# ................................................................................................- Working on pixel 100
# ...* chisq too large: pixel 102, chisq 6.28096584806
# ....................* Not enough counts: 122
# * fit failed: pixel 122
# .* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .* Not enough counts: 131
# ...

# %% [markdown]
# 11-17

# %%
for i in range(11, 17+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=1.7, dmax=2.2,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# ................................................................................................- Working on pixel 100
# ........................* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .* Not enough counts: 131
# * fit failed: pixel 131
# ....................................................................- Working on pixel 200
# ...

# %% [markdown]
# 18-22

# %%
for i in range(18, 22+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=2.5, dmax=3.5,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .................................................................................................- Working on pixel 100
# ........................* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .....................................................................- Working on pixel 200
# .....................................................* Not enough counts: 252
# * fit failed: pixel 252
# ...

# %% [markdown]
# 22 failed

# %% [markdown]
# ** C22 C60? **

# %%
calibrate.calibrate(
        pack = 'C%s/eightpack' % 22, I_tof_dir='C60-I_tof', peak_fractional_width=0.02,
        dvalues = [2.72509327,  2.89039789, 4.26940063,  5.00631601, 8.17527981],
        dmin=3.5, dmax=4.7,
        maxchisq = 100., min_counts = 50000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# ...................................................................................................- Working on pixel 100
# ...........................* Not enough counts: 126
# * fit failed: pixel 126
# ..* Not enough counts: 128
# * fit failed: pixel 128
# .......................................................................- Working on pixel 200
# .........................................................* Not enough counts: 256
# * fit failed: pixel 256
# ...........................................- Working on pixel 300
# ...................................................................................* Not enough counts: 382
# * fit failed: pixel 382
# ..* Not enough counts: 384
# * fit failed: pixel 384
# ...............- Working on pixel 400
# ...

# %% [markdown]
# ** 23,24, 27,28 **

# %%
reload(calibrate)
# Out:
# <module 'calibrate' from '/SNS/users/lj7/dv/sns-chops/detcalib/SEQ/lib/calibrate.py'>

# %%
calibrate.calibrate(
        pack = 'C%s/eightpack' % 28, I_tof_dir='C60-I_tof', peak_fractional_width=0.02,
        dvalues = [2.72509327,  2.89039789, 4.26940063,  5.00631601, 8.17527981],
        dmin=3.5, dmax=4.7,
        maxchisq = 100., min_counts = 10000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# ....................................................................................................- Working on pixel 100
# ....................................................................................................- Working on pixel 200
# ....................................................................................................- Working on pixel 300
# ....................................................................................................- Working on pixel 400
# ....................................................................................................- Working on pixel 500
# ....................................................................................................- Working on pixel 600
# ....................................................................................................- Working on pixel 700
# ...

# %%
for number in [23, 28]:
    calibrate.calibrate(
        pack = 'C%s/eightpack' % number, I_tof_dir='C60-I_tof', peak_fractional_width=0.02,
        dvalues = [2.72509327,  2.89039789, 4.26940063,  5.00631601, 8.17527981],
        dmin=3.5, dmax=4.7,
        maxchisq = 100., min_counts = 10000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# ....................................................................................................- Working on pixel 100
# ....................................................................................................- Working on pixel 200
# ....................................................................................................- Working on pixel 300
# ....................................................................................................- Working on pixel 400
# ....................................................................................................- Working on pixel 500
# ....................................................................................................- Working on pixel 600
# ....................................................................................................- Working on pixel 700
# ...

# %% [markdown]
# 24 and 27 are manually calibrated in their own notebooks

# %%
for pack in ['C25T/eightpack-top', 'C26T/eightpack-top', 'C25B/eightpack-bottom', 'C26B/eightpack-bottom']:
    calibrate.calibrate(
        pack = pack, I_tof_dir='C60-I_tof', peak_fractional_width=0.02,
        dvalues = [2.72509327,  2.89039789, 4.26940063,  5.00631601, 8.17527981],
        dmin=6, dmax=10,
        maxchisq = 150., min_counts = 10000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# .* Not enough counts: 4
# * fit failed: pixel 4
# .* Not enough counts: 5
# * fit failed: pixel 5
# ..............................................................................................- Working on pixel 100
# ..* chisq too large: pixel 101, chisq 151.179900756
# .* chisq too large: pixel 102, chisq 160.193580144
# .* chisq too large: pixel 103, chisq 163.658464485
# .* chisq too large: pixel 104, chisq 177.0516237
# .* chisq too large: pixel 105, chisq 180.484452653
# .* chisq too large: pixel 106, chisq 180.313996143
# .* chisq too large: pixel 107, chisq 198.867924888
# .* chisq too large: pixel 108, chisq 196.542707957
# .* chisq too large: pixel 109, chisq 204.170749501
# ...

# %% [markdown]
# 25,26 are calbirated in separate notebooks

# %%
calibrate.calibrate(
        pack = 'C%s/eightpack' % 29, I_tof_dir='C60-I_tof', peak_fractional_width=0.02,
        dvalues = [2.72509327,  2.89039789, 4.26940063,  5.00631601, 8.17527981],
        dmin=3.5, dmax=4.7,
        maxchisq = 100., min_counts = 50000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# ....................................................................................................- Working on pixel 100
# .............................* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# ......................................................................- Working on pixel 200
# .......................................................* Not enough counts: 254
# * fit failed: pixel 254
# ..* Not enough counts: 256
# * fit failed: pixel 256
# ...........................................- Working on pixel 300
# .....................................................................................* Not enough counts: 384
# * fit failed: pixel 384
# .* Not enough counts: 385
# * fit failed: pixel 385
# ..............- Working on pixel 400
# ...

# %% [markdown]
# 30-33

# %%
for i in range(30, 33+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=2.5, dmax=3.5,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# ................................................................................................- Working on pixel 100
# ........................* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .* Not enough counts: 131
# * fit failed: pixel 131
# ....................................................................- Working on pixel 200
# ...

# %% [markdown]
# 33--
#
# d=1.9

# %%
for i in range(33, 37+1):
    calibrate.calibrate(
        pack = 'C%s/eightpack' % i, I_tof_dir='Si-I_tof', peak_fractional_width=0.02,
        dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085],
        dmin=1.7, dmax=2.2,
        maxchisq = 5., min_counts = 1000,
        T0_of_E = calibrate.SEQ_T0_of_E,
        l2table_nxs = './L2table.nxs',
    )
# Out:
# * tof range: 2083.33333333 8333.33333333
# - Working on pixel 0
# .* Not enough counts: 0
# * fit failed: pixel 0
# .* Not enough counts: 1
# * fit failed: pixel 1
# .* Not enough counts: 2
# * fit failed: pixel 2
# .* Not enough counts: 3
# * fit failed: pixel 3
# ................................................................................................- Working on pixel 100
# .......................* Not enough counts: 122
# * fit failed: pixel 122
# .* Not enough counts: 123
# * fit failed: pixel 123
# .* Not enough counts: 124
# * fit failed: pixel 124
# .* Not enough counts: 125
# * fit failed: pixel 125
# .* Not enough counts: 126
# * fit failed: pixel 126
# .* Not enough counts: 127
# * fit failed: pixel 127
# .* Not enough counts: 128
# * fit failed: pixel 128
# .* Not enough counts: 129
# * fit failed: pixel 129
# .* Not enough counts: 130
# * fit failed: pixel 130
# .* Not enough counts: 131
# * fit failed: pixel 131
# ...
