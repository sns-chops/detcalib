# %% [markdown]
# # Difc calculation using scipy

# %%
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
import os, numpy as np
from mantid import simpleapi as msa, mtd

# %%
dvalues = [1.10860231, 1.24596143, 1.357755, 1.63751414, 1.92015553, 3.13560085]

# %%
# %%time
ws = msa.Load('/SNS/SEQ/IPTS-19573/nexus/SEQ_130273.nxs.h5')
# Out:
# CPU times: user 1min 2s, sys: 16.5 s, total: 1min 18s
# Wall time: 15.4 s

# %%
# %%time
ws = msa.CropWorkspace(InputWorkspace=ws, XMin=300, XMax=16666.7)
# Out:
# CPU times: user 3min 39s, sys: 3min 3s, total: 6min 43s
# Wall time: 27.1 s

# %% [markdown]
# ## Compute nominal difc

# %%
difc = msa.CalculateDIFC(InputWorkspace=ws)

# %%
difc = difc.extractY().flatten()

# %% [markdown]
# # Use nominal values to convert to I(d)

# %%
# %%time
I_d = msa.ConvertUnits(InputWorkspace=ws, Target='dSpacing', EMode='Elastic')
# Out:
# CPU times: user 10 s, sys: 8.45 s, total: 18.5 s
# Wall time: 18.5 s

# %%
# %%time
I_d = msa.Rebin(InputWorkspace=I_d, Params='0.4,0.01,7')
# Out:
# CPU times: user 132 ms, sys: 4 ms, total: 136 ms
# Wall time: 134 ms

# %%
I_d_100455 = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=100455, EndWorkspaceIndex=100455)

# %%
plt.figure(figsize=(7,4))
Xbb = I_d_100455.readX(0)
plt.plot( (Xbb[:-1]+Xbb[1:])/2, I_d_100455.readY(0))
plt.xlim(3,3.35)
# Out:
# <img src="data:image/png;base64,..." width="700">
# (3, 3.35)

# %% [markdown]
# Simple fitting

# %%
import scipy.optimize as sopt

# %%
x = (Xbb[:-1]+Xbb[1:])/2
y = I_d_100455.readY(0)

# %%
np.where(x>3)[0][0], np.where(x<3.3)[0][-1]
# Out:
# (260, 289)

# %%
x1 = x[260:289]
y1 = y[260:289]

# %%
plt.figure(figsize=(5,3))
plt.plot(x1,y1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
def gauss(x, *p):
    A, mu, sigma = p
    return A*np.exp(-(x-mu)**2/(2.*sigma**2))

# %%
def gauss_with_bg(x, *p):
    A, mu, sigma, bg = p
    return bg + A*np.exp(-(x-mu)**2/(2.*sigma**2))

# %%
popt, pcov = sopt.curve_fit(gauss_with_bg, x1, y1, p0=(400, 3.13, 0.05, 0))
print popt
# Out:
# [  3.30132879e+02   3.18342033e+00   5.31202012e-02   2.46274639e+01]

# %% [markdown]
# obsolete
# ```
# def cost(p):
#     y1_model = gauss(x1, *p)
#     return np.sum( (y1-y1_model)**2 )
#
# optres = sopt.minimize(cost, x0=(400, 3.13, 0.05))
#
# optres.x
# ```

# %%
plt.figure(figsize=(5,3))
plt.errorbar(x1, y1, yerr=np.sqrt(y1))
plt.plot(x1, gauss_with_bg(x1, *popt))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# goodness of fit?

# %%
chisq = np.average((y1 - gauss_with_bg(x1, *popt))**2 / y1)

# %%
chisq
# Out:
# 2.1147544856024143

# %%
difc[100455]
# Out:
# 2023.9221907717592

# %% [markdown]
# new difc

# %%
difc[100455]*optres.x[1]/3.13560085
# Out:
# 2054.3365999208204

# %% [markdown]
# ## Loop over all pixels in D23

# %%
N = I_d.getNumberHistograms()

# %%
newdifc = difc.copy()

# %%
mask = np.zeros(difc.shape, dtype=bool)
chisq = np.zeros(difc.shape, dtype=float)

# %%
firstindex = 100352
lastindex = 101375

# %%
# %%time
d_target = 3.13560085
for pixel in range(firstindex, lastindex+1):
    if (pixel%100)==0 : print pixel
    I_d_pixel = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=pixel, EndWorkspaceIndex=pixel)
    Xbb = I_d_pixel.readX(0)
    x = (Xbb[:-1]+Xbb[1:])/2
    y = I_d_pixel.readY(0)
    startindex, stopindex = np.where(x>2.8)[0][0], np.where(x<3.5)[0][-1]
    x1 = x[startindex:stopindex]
    y1 = y[startindex:stopindex]
    p0 = np.max(y1), x1[np.argmax(y1)], 0.1, 0
    try:
        popt, pcov = sopt.curve_fit(gauss_with_bg, x1, y1, p0=p0)
    except:
        mask[pixel] = 1
        continue
    chisq[pixel] = np.average((y1 - gauss_with_bg(x1, *popt))**2 / y1)
    center = popt[1]
    newdifc[pixel] = difc[pixel] * center / d_target
    continue
# Out:
# /home/lj7/miniconda2/envs/mantid/lib/python2.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in divide
# 100400
# /home/lj7/miniconda2/envs/mantid/lib/python2.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in divide
# 100500
# 100600
# 100700
# 100800
# 100900
# 101000
# 101100
# 101200
# 101300
# CPU times: user 11.8 s, sys: 2.95 s, total: 14.7 s
# Wall time: 11.3 s

# %%
chisq_d23 = chisq[firstindex:lastindex+1]
chisq_d23.shape = 8, 128
chisq_d23
# Out:
# array([[  0.,  inf,  inf, ...,  inf,  inf,  inf],
#        [ nan,  inf,  inf, ...,  inf,  inf,  nan],
#        [ inf,  inf,  inf, ...,  inf,  inf,  inf],
#        ...,
#        [ nan,  inf,  inf, ...,  inf,  inf,  inf],
#        [ nan,   0.,  inf, ...,  inf,  inf,  inf],
#        [ nan,  inf,  inf, ...,  inf,  nan,  nan]])

# %%
chisq_d23[np.logical_not( np.isinf(chisq_d23) )]
# Out:
# array([ 0.        ,  1.25613055,  1.40583566,  0.92932938,  1.74930189,
#         1.60014082,  1.9125223 ,  1.51820389,  1.01534275,  1.22178233,
#         0.95689665,  1.15700046,  1.18401267,  1.23194821,  0.92185499,
#         1.12089806,  1.57003457,  0.96148817,  0.97881957,  1.40680515,
#         0.93840241,  1.19043401,  2.28838418,  1.61926504,  1.71388982,
#         1.14548896,  1.27168356,  1.12789666,  1.09266695,  1.7244095 ,
#         1.32057354,  1.19437664,  1.57301534,  1.23292456,  2.30280502,
#         1.73307509,  1.83492148,  2.41390982,  1.21591029,  1.98438312,
#         1.75750344,  3.68380081,  2.29428844,  1.35698573,  1.97820235,
#         1.9907441 ,  1.5050929 ,  3.20469227,  1.6566307 ,  1.68825491,
#         2.6481109 ,  1.81182076,  2.73197349,  1.83132779,  2.25434345,
#         2.28821305,  2.7421344 ,  2.88821625,  2.78215134,  2.33136379,
#         2.08920936,  2.46869341,  2.2183419 ,  2.3285615 ,  2.65845595,
#         2.08067476,  2.38484683,  2.52315476,  2.07111636,  2.78149189,
#         2.06422056,  1.9391527 ,  2.2300116 ,  2.12202548,  2.01376506,
#         1.60704543,  2.22286552,  1.92470349,  1.6729728 ,  1.85349415,
#         1.82607788,  1.89789565,  2.10549779,  1.40562568,  1.53925577,
#         1.12970549,  1.66724168,  1.31992733,  1.25932339,  1.5662224 ,
#         1.69828777,  1.55444479,  0.76728205,  1.00003974,  1.36422532,
#         1.36280845,  1.41202371,  1.28503454,  1.2938019 ,  1.28615842,
#         1.68950389,  1.2617338 ,  1.47504725,  1.31407335,  1.66272323,
#         1.33429448,  1.22617124,  1.97554887,  1.4335577 ,  1.54873969,
#         1.2744875 ,  1.39779875,  1.8062445 ,  1.86075107,  2.21475739,
#         1.77860486,  1.77575242,  2.12545733,  1.93408851,  1.60598303,
#         1.49471185,         nan,  1.27598653,  1.32136421,  1.10066005,
#         1.04000491,  2.0723218 ,  1.26043947,  1.01192308,  1.14162612,
#         1.27006109,  1.52697846,  1.99705547,  1.08156862,  1.388695  ,
#         1.79363874,  1.76418982,  2.15021661,  1.32765137,  0.94479599,
#         1.39875505,  1.90195585,  1.27934338,  1.09982156,  1.10987956,
#         2.06534293,  2.09258516,  1.38506899,  1.22096994,  1.14427152,
#         0.8600086 ,  1.12050146,  1.1910294 ,  1.4436665 ,  1.3210592 ,
#         1.40094553,  1.55591125,  1.91725671,  1.51606283,  2.15959649,
#         1.26567067,  1.67677311,  2.86900517,  1.7603619 ,  2.22191331,
#         1.8555892 ,  2.39489757,  2.13147541,  1.92859031,  1.90170321,
#         1.95496368,  2.69443212,  2.42518098,  2.06296888,  1.81515612,
#         2.55527461,  2.44935331,  2.53371626,  1.78638848,  2.65256137,
#         1.81010087,  2.64842562,  2.25152484,  2.80585726,  2.54256765,
#         2.43937262,  2.17752269,  2.59228093,  2.50159602,  2.8569731 ,
#         2.56009024,  1.68068271,  1.88870005,  2.17315971,  2.05302372,
#         2.38165831,  2.35690179,  1.83501802,  2.49480963,  2.1066532 ,
#         2.03259841,  1.81886562,  1.88618896,  1.48123298,  1.40420972,
#         1.44455154,  1.6010011 ,  1.57155263,  1.87631699,  1.93530296,
#         1.56205274,  2.19072472,  1.95912165,  1.50732725,  1.42515383,
#         1.63291478,  1.62894301,  1.79405573,  1.23055512,  1.2099149 ,
#         1.36009018,  1.45820468,  1.53231337,  1.74098924,  1.23847985,
#         1.75853357,  1.66001819,  1.8329877 ,  1.56965053,  2.05169301,
#         1.65042795,  1.67743994,  1.9674837 ,  1.82668936,  1.48875368,
#         1.52675027,  1.84348475,  2.12372986,  2.27523987,  2.17245858,
#         1.5938125 ,  1.09941258,         nan,  1.36832043,  1.24101019,
#         1.50876415,  0.75843289,  1.84013148,  1.25393709,  1.00336645,
#         1.2863947 ,  1.21830463,  1.46526879,  0.76777508,  1.57647184,
#         0.83138112,  2.42646576,  1.6575483 ,  1.3747817 ,  0.95950699,
#         1.79777165,  2.58890701,  1.42799283,  1.61966092,  1.00012624,
#         2.22928894,  1.54489604,  1.32325891,  1.70350293,  1.10300705,
#         1.28368985,  1.44495686,  1.11029964,  1.94999766,  1.20863963,
#         1.42784881,  2.71229348,  1.43967023,  1.64886483,  1.52541165,
#         2.13125976,  1.88169006,  1.57512827,  1.61288509,  1.70403854,
#         1.40773891,  1.05668291,  2.60745186,  2.15861866,  1.82614833,
#         2.18347487,  2.26074937,  1.69209871,  3.59595359,  1.67189307,
#         2.49314102,  2.40115242,  1.9179707 ,  1.53751661,  2.06858055,
#         2.64980752,  2.08432884,  2.36414832,  2.30786287,  2.7794432 ,
#         2.68549724,  3.05901951,  2.14995263,  2.40186961,  2.49288145,
#         2.60736944,  2.17297778,  2.58621264,  2.64502751,  3.45330617,
#         2.24694293,  1.99069653,  2.51471701,  2.30748032,  3.12043023,
#         2.0729602 ,  2.04457693,  1.8578766 ,  2.14426783,  1.74492477,
#         2.34851732,  1.58145963,  1.55851231,  1.40112107,  1.6896014 ,
#         2.04591168,  1.48827039,  1.63771213,  1.64778751,  1.50423445,
#         1.96382315,  1.97967358,  1.57099621,  1.78526735,  1.6014995 ,
#         1.74427892,  1.04139371,  1.21587881,  1.4336718 ,  1.23244302,
#         2.12339077,  1.74613666,  1.73914773,  1.75157499,  1.69973531,
#         1.68058811,  1.7818324 ,  2.01346027,  2.30594232,  1.6503493 ,
#         1.93668839,  1.32832602,  2.04169666,  1.70391745,  2.64908483,
#         3.80354458,  1.88769832,  1.69624214,         nan,  1.68800392,
#         2.44178592,  1.12592776,  1.85237619,  2.23278151,  1.44251895,
#         1.66988704,  1.35374801,  1.28344381,  1.00943674,  1.08499224,
#         1.22050182,  1.16598219,  1.56582075,  1.7691827 ,  1.11634033,
#         2.79372971,  1.43899044,  2.35023278,  1.3391951 ,  1.11248672,
#         1.09425089,  1.31409556,  1.46628199,  1.05298492,  1.17592985,
#         1.39689524,  1.41311318,  1.26965278,  1.85624643,  1.60989371,
#         1.89841353,  1.39815746,  1.61577835,  1.36282601,  2.10013319,
#         1.92963601,  1.43927168,  1.6789512 ,  1.73332824,  1.31744441,
#         1.18249985,  2.06589809,  2.03761799,  1.92326595,  2.54926434,
#         1.75937626,  2.1991263 ,  2.1541627 ,  2.25984067,  1.96961563,
#         2.6661323 ,  2.26347056,  3.07054035,  2.44320956,  1.56031028,
#         2.01355368,  1.7596771 ,  2.75361243,  2.71612893,  2.59902744,
#         2.42527405,  2.96214844,  2.65391305,  2.36978591,  1.966549  ,
#         2.27655082,  1.8075142 ,  3.33270873,  2.73710604,  2.02188663,
#         2.62991217,  1.77106965,  2.57686897,  2.0689876 ,  3.03400728,
#         1.74280321,  2.23250515,  2.50098055,  1.91441955,  2.87133347,
#         2.88635138,  1.41954106,  1.81518566,  1.80718072,  1.5163317 ,
#         1.47990288,  1.88647415,  1.4115844 ,  1.4967535 ,  1.53116527,
#         1.19898444,  1.91121796,  1.71663759,  1.34129499,  1.79368158,
#         1.90244979,  1.75266697,  1.48712124,  1.80777092,  1.3142952 ,
#         1.75668144,  1.26802177,  1.75553565,  1.74929201,  1.57863901,
#         1.53795016,  2.13733445,  1.24582076,  1.87604752,  2.05395461,
#         1.50033974,  2.03168593,  2.05590974,  2.14357742,  2.33532441,
#         1.92401241,  1.11820491,         nan,         nan,  0.95015768,
#         0.95875247,  1.63314201,  1.28235744,  1.01655617,  1.56222682,
#         1.222626  ,  1.35643783,  2.20851489,  1.10114579,  1.25226175,
#         1.06541499,  1.60456122,  1.00296181,  1.24640546,  1.57518549,
#         0.93831166,  1.03504044,  1.41824535,  1.55136711,  0.98659839,
#         0.93451632,  1.77868407,  1.2941612 ,  1.42720368,  1.27001861,
#         1.40915836,  1.27040485,  1.21007925,  1.27490051,  0.94983774,
#         0.97181305,  1.67128653,  1.5438659 ,  1.64947911,  1.46293079,
#         1.02900624,  1.07025035,  1.12621901,  1.45516098,  1.81336645,
#         1.55172784,  1.73557663,  1.39556651,  1.3976928 ,  1.60976767,
#         2.05464027,  2.57314076,  2.06519321,  1.57453028,  1.70190841,
#         2.28353912,  3.08218431,  1.98566268,  2.11250569,  1.7351944 ,
#         3.67005002,  1.73728364,  2.80758941,  2.68712443,  2.54864016,
#         2.11227025,  1.56089104,  1.78247059,  1.87536639,  2.33908419,
#         2.75538837,  2.25971699,  1.88568112,  1.76312979,  2.08558089,
#         2.24144947,  2.56296852,  1.56026256,  2.06939359,  2.41652109,
#         2.18943109,  2.43899756,  1.89527221,  2.41591975,  2.30315989,
#         1.9833069 ,  2.04882567,  2.29147534,  1.3121027 ,  2.04648713,
#         1.90594808,  1.82159072,  1.46700927,  1.59350816,  1.99496328,
#         1.17145005,  1.7153577 ,  1.66468307,  1.60625617,  2.17215204,
#         1.97071495,  2.11874393,  2.62500112,  1.62900174,  2.04278039,
#         1.7608671 ,  1.44731402,  1.76070222,  1.67724439,  1.94798478,
#         1.29249386,  2.67118066,  2.42398167,  2.53320557,  1.82323207,
#         2.60448508,  2.06296179,  1.47129799,         nan,         nan,
#                nan,  1.19411971,  1.74719936,  0.98507866,  1.87441849,
#         1.39106453,  1.02474534,  1.04283973,  1.41130388,  1.03252101,
#         2.00263063,  0.97201012,  1.4425879 ,  1.29677823,  1.32784369,
#         1.06197441,  1.22903946,  1.63385641,  1.39755934,  1.42781728,
#         1.07316593,  1.96299556,  1.82284389,  1.11099552,  1.52110201,
#         1.22533735,  1.70064278,  1.42926642,  1.40627522,  1.47798208,
#         1.76213731,  1.73585256,  1.54628599,  1.05264494,  1.97521454,
#         1.75876174,  2.20250242,  1.27189386,  1.30623531,  1.9988592 ,
#         1.74610468,  2.45144847,  1.66753151,  3.46540089,  1.40051793,
#         1.5704148 ,  1.58420132,  1.41109464,  2.23469425,  2.67162682,
#         1.7400381 ,  1.69313036,  2.47384426,  2.29906692,  2.15069219,
#         2.24297583,  2.73458391,  2.38836974,  2.12979051,  2.7296194 ,
#         2.58751513,  2.37512224,  2.30716879,  2.36967762,  1.66824867,
#         2.25038808,  3.14909301,  2.86684897,  2.69164337,  3.28314067,
#         2.81864222,  2.93314279,  2.55229265,  2.54569106,  2.91261518,
#         2.46481079,  1.89170828,  1.7768037 ,  2.5061501 ,  2.2320759 ,
#         2.17996335,  1.63059047,  2.92127821,  2.32134271,  2.24487009,
#         2.13996366,  2.00606958,  1.79137542,  2.12749918,  1.37457275,
#         1.61674522,  1.44414581,  1.70684902,  2.24415815,  2.15688377,
#         1.56694281,  2.15535265,  1.61732107,  1.78143321,  1.12999973,
#         1.82294058,  1.90696433,  1.66877762,  1.74462605,  1.56275266,
#         1.76745556,  1.57509853,  1.93071183,  1.5948878 ,  1.54065897,
#         1.98589749,  1.81966711,  1.86125731,  2.01337726,  2.276668  ,
#         2.3003341 ,  2.12847888,  1.61054706,  1.35547027,         nan,
#         0.        ,  1.30294419,  1.26429364,  2.03800337,  1.08529629,
#         1.23381352,  1.90781696,  1.58427343,  1.18839896,  1.35672899,
#         0.99886919,  1.356672  ,  1.62772488,  1.21362389,  1.32893705,
#         2.71135855,  1.45215765,  1.01313765,  1.23627449,  2.03928005,
#         1.34789792,  1.46666907,  1.32561896,  0.98163745,  2.33371939,
#         1.18996036,  1.79196376,  1.05858286,  1.15388597,  1.39096195,
#         2.13011885,  1.26017531,  1.49562328,  1.45175497,  1.70834403,
#         0.91481907,  2.11626438,  1.65444645,  1.21293318,  1.38706097,
#         1.65214632,  1.83153745,  1.35385262,  1.6289296 ,  2.65220801,
#         1.50913062,  1.97919224,  1.82496813,  1.97425557,  1.60370452,
#         1.55658752,  1.95134436,  3.08690666,  2.85249432,  2.07481192,
#         1.94225419,  2.73217963,  2.28785066,  2.66278899,  2.76466179,
#         2.15561917,  3.18468379,  3.0151428 ,  3.48361078,  2.24554212,
#         2.31977483,  2.7969733 ,  3.3355392 ,  3.08944771,  2.09842758,
#         2.90652031,  2.29227934,  2.74401682,  2.8971693 ,  2.89059177,
#         1.94477959,  1.89246671,  2.24430391,  2.15479187,  2.47602137,
#         2.32154571,  1.86424101,  2.41889755,  2.52579383,  2.92731689,
#         1.55024967,  1.69535662,  1.63425224,  2.15459455,  2.212048  ,
#         2.46662275,  1.74136329,  1.87813325,  1.83970308,  1.81444392,
#         1.84766824,  1.68886992,  1.74442045,  2.08111669,  2.15372488,
#         1.76675354,  2.15039045,  1.77004996,  1.75613333,  2.187415  ,
#         2.05589578,  2.19398984,  1.6117265 ,  2.11928017,  1.62472953,
#         1.79041755,  2.37276375,  1.97248342,  2.33168629,  2.0334299 ,
#         2.01856939,  2.22589216,  2.67187382,  1.26056689,         nan,
#         0.91904465,  1.26608592,  1.45078661,  1.09900777,  1.38868227,
#         1.14943151,  1.98611471,  1.14723701,  0.95756911,  1.13600093,
#         1.30032972,  1.41534963,  1.76312303,  1.39440642,  1.44504148,
#         1.05793807,  1.517437  ,  1.23361094,  1.25910008,  0.95810464,
#         1.62549712,  2.01829275,  1.50935991,  1.74753711,  1.35000922,
#         1.24707798,  1.00290694,  1.63998506,  1.45753929,  1.51251347,
#         1.57083065,  1.10999008,  1.39953234,  1.1788522 ,  1.32208985,
#         1.99910744,  1.34134859,  1.41341632,  1.85043092,  1.56590268,
#         1.77617598,  2.03081419,  1.71072152,  2.25734707,  1.73765484,
#         1.94244137,  2.62875059,  3.76443933,  1.31811773,  1.64274731,
#         2.06716393,  2.6158457 ,  1.74337661,  3.03418203,  1.94647071,
#         2.34931621,  1.94295464,  2.7744583 ,  2.08338582,  2.1876651 ,
#         2.55603499,  1.8661178 ,  2.19740517,  2.82904316,  1.92161969,
#         2.59239425,  2.28766015,  2.7869585 ,  3.23408562,  2.41471503,
#         2.07990966,  2.60631942,  2.37524245,  1.90608731,  1.80771274,
#         2.29003223,  2.48990824,  2.00057195,  1.94740885,  1.78169263,
#         2.19646081,  1.8866003 ,  1.61483078,  2.72471346,  1.73517033,
#         1.55105396,  0.90173695,  1.68715296,  1.57273867,  1.08794382,
#         1.55657306,  1.67461444,  1.43506953,  1.39668417,  1.29080089,
#         1.45730876,  1.72414325,  1.63623425,  1.41705275,  1.23511377,
#         1.74111057,  1.79200396,  1.97417438,  2.32125048,  1.52719792,
#         1.36826633,  2.14174706,  1.83879145,  2.47534316,  1.53536086,
#         1.82305313,  1.84640493,  2.3333008 ,  2.12967526,  1.32289445,
#                nan,         nan])

# %%
np.max(chisq_d23[np.isfinite(chisq_d23)])
# Out:
# 3.8035445810431452

# %%
np.where(chisq_d23 == np.max(chisq_d23[np.isfinite(chisq_d23)]))
# Out:
# (array([2]), array([121]))

# %%
firstindex + 2*128+121
# Out:
# 100729

# %%
firstindex + 4*128+18
# Out:
# 100882

# %%
mask[np.logical_not(np.isfinite(chisq))] = 1

# %%
np.save('difc-2-D23-mask.npy', mask)

# %%
np.save('difc-2-D23-difc.npy', newdifc)

# %% [markdown]
# # Check 100729

# %%
I_d_100729 = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=100729, EndWorkspaceIndex=100729)

# %%
Xbb = I_d_100729.readX(0)
Y = I_d_100729.readY(0)

# %%
X = (Xbb[1:] + Xbb[:-1])/2

# %%
plt.figure(figsize=(5,3))
plt.plot(X,Y)
# plt.xlim(3, 3.5)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
startindex, stopindex = np.where(X>2.8)[0][0], np.where(X<3.5)[0][-1]
X1 = X[startindex:stopindex]
Y1 = Y[startindex:stopindex]

# %%
plt.figure(figsize=(5,3))
plt.plot(X1,Y1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
popt, pcov = sopt.curve_fit(gauss_with_bg, X1, Y1, p0=(400, 3.13, 0.05, 0))
print popt
# Out:
# [  4.13256309e+02   3.19789048e+00   4.84076210e-02   3.86891537e+01]

# %%
plt.figure(figsize=(5,3))
plt.errorbar(X1, Y1, yerr=np.sqrt(Y1))
plt.plot(X1, gauss_with_bg(X1, *popt))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
np.average((Y1 - gauss_with_bg(X1, *popt))**2 / Y1)
# Out:
# 3.8035875094607214

# %% [markdown]
# # Check 100882
# This was done when the init guess was not obtained from data.
# The fitting result was then not optimal.
# Later in this section we put in a better initial guess and the result was good.

# %%
I_d_100882 = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=100882, EndWorkspaceIndex=100882)

# %%
Xbb = I_d_100882.readX(0)
Y = I_d_100882.readY(0)

# %%
X = (Xbb[1:] + Xbb[:-1])/2

# %%
plt.figure(figsize=(5,3))
plt.plot(X,Y)
# plt.xlim(3, 3.5)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
startindex, stopindex = np.where(X>2.8)[0][0], np.where(X<3.5)[0][-1]
X1 = X[startindex:stopindex]
Y1 = Y[startindex:stopindex]

# %%
plt.figure(figsize=(5,3))
plt.plot(X1,Y1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
popt, pcov = sopt.curve_fit(gauss_with_bg, X1, Y1, p0=(400, 3.13, 0.05, 0))
print popt
# Out:
# [-22.10247946   3.30661817   0.15284577  24.91270788]

# %%
plt.figure(figsize=(5,3))
plt.errorbar(X1, Y1, yerr=np.sqrt(Y1))
plt.plot(X1, gauss_with_bg(X1, *popt))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
popt, pcov = sopt.curve_fit(gauss_with_bg, X1, Y1, p0=(60, 3., 0.05, 0))
print popt
# Out:
# [  5.05073563e+01   2.96736415e+00   4.20948025e-02   6.33455700e+00]

# %%
plt.figure(figsize=(5,3))
plt.errorbar(X1, Y1, yerr=np.sqrt(Y1))
plt.plot(X1, gauss_with_bg(X1, *popt))
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
X1[np.argmax(Y1)], np.max(Y1)
# Out:
# (2.9649999999999808, 67.0)

# %% [markdown]
# # Check aligned I(d)

# %%
t = msa.Load('./difc_cal.nxs')

# %%
t.getColumnNames()
# Out:
# ['detid', 'difc', 'difa', 'tzero', 'tofmin', 'tofmax']

# %%
tzero = np.array(t.column('tzero'))

# %%
np.all(tzero==0)
# Out:
# True

# %%
for i, v in enumerate(newdifc):
    t.setCell('difc', i, v)
    continue

# %%
# %%time
aligned = msa.AlignDetectors(InputWorkspace=ws, CalibrationWorkspace=t)
# Out:
# CPU times: user 21 s, sys: 27.8 s, total: 48.8 s
# Wall time: 19.5 s

# %%
# %%time
aligned = msa.CropWorkspace(InputWorkspace='aligned', XMin=0.4, XMax=7)
# Out:
# CPU times: user 38.7 s, sys: 41 s, total: 1min 19s
# Wall time: 6.08 s

# %%
# %%time
I_d = msa.Rebin(InputWorkspace=aligned, Params='0.4,0.0005,7')
# Out:
# CPU times: user 5.5 s, sys: 1.47 s, total: 6.97 s
# Wall time: 5.92 s

# %%
I_d_pack_d23 = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=100352, EndWorkspaceIndex=101375)

# %%
x_bb = I_d_pack_d23.readX(0); y = I_d_pack_d23.readY(0)
x = (x_bb[1:] + x_bb[:-1])/2
plt.figure(figsize=(7,4))
plt.plot(x,y, label='aligned')
plt.xlim(3,3.3)
plt.legend(loc='upper left')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
I_d_100455 = msa.SumSpectra(InputWorkspace=I_d, StartWorkspaceIndex=100455, EndWorkspaceIndex=100455)

# %%
plt.figure(figsize=(7,4))
Xbb = I_d_100455.readX(0)
plt.plot( (Xbb[:-1]+Xbb[1:])/2, I_d_100455.readY(0))
plt.xlim(3,3.35)
# Out:
# <img src="data:image/png;base64,..." width="576">
# (3, 3.35)
