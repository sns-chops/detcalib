# %%
workdir = "/SNS/users/lj7/dv/sns-chops/detcalib/ARCS/out/"
# %cd {workdir}
# Out:
# /SNS/users/lj7/dv/sns-chops/detcalib/ARCS/out

# %%
import os, numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
ls diamond-I_tof/
# Out:
# detIDs.npy     I_tof-y-B1.npy  I_tof-y_matrix.npy  pack-B2.yaml
# I_tof-xbb.npy  I_tof-y-B2.npy  pack-B1.yaml

# %%
xbb = np.load('./diamond-I_tof/I_tof-xbb.npy')
y_B1 = np.load('./diamond-I_tof/I_tof-y-B1.npy')

# %%
x = (xbb[:-1] + xbb[1:])/2

# %%
plt.plot(x, y_B1[120+128*7])
# Out:
# <img src="data:image/png;base64,..." width="640">
